# %% [markdown]
# # SatQuery AI — Remote-Sensing VLM Adaptation
# Upload an RSVQA/BigEarthNet-derived JSONL dataset, then run the reproducible adapter entry point. Record the final artifact in `Docs/training_runs/`.

# %%
# !pip install -q transformers peft accelerate datasets pillow
# !git clone <YOUR_SATQUERY_REPOSITORY_URL> satquery
# %cd satquery

# %%
# !python experiments/adaptation/train_lora.py --train-jsonl /content/train.jsonl --output-dir /content/checkpoints/rsvqa-blip-lora
